# %%
import yfinance as yf
import pandas as pd

tickers = ['SPY', 'AAPL', 'TSLA', 'GLD', 'BTC-USD']
data = yf.download(tickers, start='2015-01-01', end='2024-12-31')
data = data.dropna()
data.head()
# Out:
# [*********************100%***********************]  5 of 5 completed
# Price           Close                                                 \
# Ticker           AAPL     BTC-USD         GLD         SPY       TSLA
# Date
# 2015-01-02  24.288582  315.032013  114.080002  172.075241  14.620667
# 2015-01-05  23.604334  274.473999  115.800003  168.967621  14.006000
# 2015-01-06  23.606550  286.188995  117.120003  167.376099  14.085333
# 2015-01-07  23.937572  294.337006  116.430000  169.461807  14.063333
# 2015-01-08  24.857311  283.348999  115.940002  172.468918  14.041333
#
# Price            High                                                 ...  \
# Ticker           AAPL     BTC-USD         GLD         SPY       TSLA  ...
# Date                                                                  ...
# 2015-01-02  24.757336  315.838989  114.800003  173.289821  14.883333  ...
# 2015-01-05  24.137514  278.341003  116.000000  171.187347  14.433333  ...
# ...

# %%
weekly_data = data.resample('W').last()
weekly_data.head()
# Out:
# Price           Close                                                 \
# Ticker           AAPL     BTC-USD         GLD         SPY       TSLA
# Date
# 2015-01-04  24.288582  315.032013  114.080002  172.075241  14.620667
# 2015-01-11  24.883965  290.407990  117.260002  171.086838  13.777333
# 2015-01-18  23.546574  208.097000  122.519997  168.892258  12.871333
# 2015-01-25  25.099459  232.878998  124.230003  171.689926  13.419333
# 2015-02-01  26.028080  226.425003  123.449997  167.066208  13.573333
#
# Price            High                                                 ...  \
# Ticker           AAPL     BTC-USD         GLD         SPY       TSLA  ...
# Date                                                                  ...
# 2015-01-04  24.757336  315.838989  114.800003  173.289821  14.883333  ...
# 2015-01-11  25.159440  291.114014  117.339996  172.904503  13.998667  ...
# 2015-01-18  23.899806  221.591003  123.150002  169.051410  12.966000  ...
# ...
